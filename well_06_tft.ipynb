# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch

# %%
from src.vfm.connection import Connection
from src.vfm.preprocessor import Preprocessor
import pandas as pd
from src.vfm.model.nn.tft import TemporalFusionTransformerModel

# %%
connection = Connection()

# Add the parent directory to the sys.path list
# sys.path.insert(0, os.path.abspath('..'))

# Get client
client = connection.get_client()

# %%
well = 'W06'
df_raw = connection.get_data(client, well = well, start=pd.Timestamp('2019-01-01'), end=pd.Timestamp('2023-01-30'))
# df_raw = connection.get_data(client, well = well)
df_raw.shape
# Out:
# (2085243, 12)

# %%
oldest_ts_per_field = df_raw.notna().apply(lambda col: col.index[col].min())
oldest_ts_per_field
# Out:
# whp            2017-03-06 02:38:00
# wht            2017-03-06 02:38:00
# dhp            2017-03-06 02:38:00
# dht            2017-03-06 02:38:00
# choke          2017-03-06 02:38:00
# dcp            2017-03-06 02:38:00
# qo_well_test   2019-01-30 20:39:00
# qg_well_test   2019-01-30 20:39:00
# qw_well_test   2019-01-30 20:39:00
# qo_mpfm        2017-03-06 02:38:00
# qg_mpfm        2017-03-06 02:38:00
# wc_mpfm        2017-03-06 02:38:00
# dtype: datetime64[ns]

# %%
latest_ts_per_field = df_raw.notna().iloc[::-1].idxmax()
latest_ts_per_field
# Out:
# whp            2023-05-07 07:24:00
# wht            2023-05-07 07:24:00
# dhp            2023-05-07 07:24:00
# dht            2023-05-07 07:24:00
# choke          2023-05-07 07:24:00
# dcp            2023-05-07 07:24:00
# qo_well_test   2023-01-17 20:24:00
# qg_well_test   2023-01-17 20:24:00
# qw_well_test   2023-01-17 20:24:00
# qo_mpfm        2023-05-07 07:24:00
# qg_mpfm        2023-05-07 07:24:00
# wc_mpfm        2023-05-07 07:24:00
# dtype: datetime64[ns]

# %%
timestamps = df_raw.index[df_raw["qo_well_test"].notna()].to_list()
timestamps
# Out:
# [Timestamp('2019-01-30 20:39:00'),
#  Timestamp('2019-01-31 04:57:00'),
#  Timestamp('2019-01-31 13:30:00'),
#  Timestamp('2019-03-02 15:21:00'),
#  Timestamp('2019-03-04 08:21:00'),
#  Timestamp('2019-03-10 17:42:00'),
#  Timestamp('2019-04-14 16:54:00'),
#  Timestamp('2019-04-15 16:55:00'),
#  Timestamp('2019-04-15 23:44:00'),
#  Timestamp('2019-04-16 07:08:00'),
#  Timestamp('2019-05-22 17:07:00'),
#  Timestamp('2019-05-24 05:19:00'),
#  Timestamp('2019-05-24 07:50:00'),
#  Timestamp('2019-05-24 10:48:00'),
#  Timestamp('2019-05-24 17:02:00'),
#  Timestamp('2019-05-25 20:16:00'),
#  Timestamp('2019-05-26 05:12:00'),
#  Timestamp('2019-05-26 06:59:00'),
#  Timestamp('2019-05-26 10:20:00'),
#  Timestamp('2019-05-26 18:57:00'),
#  Timestamp('2019-05-27 01:57:00'),
#  Timestamp('2019-05-27 08:01:00'),
#  Timestamp('2019-07-05 09:49:00'),
#  Timestamp('2019-07-05 22:05:00'),
#  Timestamp('2019-08-27 21:52:00'),
#  Timestamp('2019-08-28 01:12:00'),
#  Timestamp('2019-08-28 06:02:00'),
#  Timestamp('2019-08-28 08:06:00'),
#  Timestamp('2019-09-02 22:27:00'),
#  Timestamp('2019-09-03 05:30:00'),
#  Timestamp('2019-09-28 04:00:00'),
#  Timestamp('2019-10-13 08:31:00'),
#  Timestamp('2021-10-02 01:09:00'),
#  Timestamp('2021-10-03 07:40:00'),
#  Timestamp('2021-10-04 18:09:00'),
#  Timestamp('2021-10-05 08:21:00'),
#  Timestamp('2021-10-05 11:17:00'),
#  Timestamp('2021-10-05 19:55:00'),
#  Timestamp('2021-10-05 23:42:00'),
#  Timestamp('2021-10-06 19:59:00'),
#  Timestamp('2021-10-07 07:07:00'),
#  Timestamp('2021-12-01 10:21:00'),
#  Timestamp('2021-12-01 14:43:00'),
#  Timestamp('2021-12-02 03:25:00'),
#  Timestamp('2021-12-02 15:37:00'),
#  Timestamp('2022-01-25 18:56:00'),
#  Timestamp('2022-01-25 23:24:00'),
#  Timestamp('2022-01-26 01:41:00'),
#  Timestamp('2022-01-26 03:02:00'),
#  Timestamp('2022-01-26 06:34:00'),
#  Timestamp('2022-07-08 08:25:00'),
#  Timestamp('2022-07-08 09:33:00'),
#  Timestamp('2022-07-08 11:38:00'),
#  Timestamp('2022-07-08 14:49:00'),
#  Timestamp('2022-07-08 18:54:00'),
#  Timestamp('2022-07-08 20:23:00'),
#  Timestamp('2022-07-09 08:49:00'),
#  Timestamp('2022-07-09 11:37:00'),
#  Timestamp('2022-07-10 00:19:00'),
#  Timestamp('2022-07-10 09:11:00'),
#  Timestamp('2022-07-10 11:19:00'),
#  Timestamp('2022-07-10 12:38:00'),
#  Timestamp('2022-07-10 14:38:00'),
#  Timestamp('2022-07-10 17:53:00'),
#  Timestamp('2022-07-10 21:34:00'),
#  Timestamp('2022-07-10 23:52:00'),
#  Timestamp('2022-07-11 12:12:00'),
#  Timestamp('2022-09-08 16:02:00'),
#  Timestamp('2022-10-23 15:24:00'),
#  Timestamp('2022-10-24 00:13:00'),
#  Timestamp('2022-10-24 05:11:00'),
#  Timestamp('2022-10-24 09:04:00'),
#  Timestamp('2022-10-24 11:02:00'),
#  Timestamp('2023-01-11 01:57:00'),
#  Timestamp('2023-01-11 13:05:00'),
#  Timestamp('2023-01-11 14:46:00'),
#  Timestamp('2023-01-11 18:17:00'),
#  Timestamp('2023-01-11 20:22:00'),
#  Timestamp('2023-01-11 22:29:00'),
#  Timestamp('2023-01-12 06:59:00'),
#  Timestamp('2023-01-12 12:48:00'),
#  Timestamp('2023-01-12 18:38:00'),
#  Timestamp('2023-01-12 22:24:00'),
#  Timestamp('2023-01-12 23:41:00'),
#  Timestamp('2023-01-13 01:49:00'),
#  Timestamp('2023-01-13 06:24:00'),
#  Timestamp('2023-01-13 10:18:00'),
#  Timestamp('2023-01-13 23:46:00'),
#  Timestamp('2023-01-15 05:22:00'),
#  Timestamp('2023-01-15 14:25:00'),
#  Timestamp('2023-01-16 03:25:00'),
#  Timestamp('2023-01-16 05:04:00'),
#  Timestamp('2023-01-16 21:25:00'),
#  Timestamp('2023-01-16 23:23:00'),
#  Timestamp('2023-01-17 20:24:00')]

# %%
preprocessor = Preprocessor(df=df_raw)
df = preprocessor.preprocess_timeseries()
df.shape
# Out:
# (234, 13)

# %%
from sklearn.model_selection import train_test_split

# Select all independent variables.
X = df[['time_step', 'dhp', 'dht', 'whp', 'wht', 'choke', 'dcp']]
# Select only the target variable.
Y = df[['qo_mpfm', 'qg_mpfm', 'qw_mpfm']]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=65)

# %%
# Training data
print(f'Train data records  {X_train.shape}')


# Testing data
print(f'Test data records {X_test.shape}')
# Out:
# Train data records  (56, 7)
# Test data records (14, 7)

# %% [markdown]
# # Temporal Fusion Transformer Model - Well 06

# %%
tft_train_df = df[['time_step', 'dhp', 'dht', 'whp', 'wht', 'choke', 'dcp', 'qo_mpfm', 'qg_mpfm', 'qw_mpfm']]
tft_train_df['well'] = well
tft_train_df = tft_train_df.reset_index(drop=True)
tft_train_df
# Out:
# C:\Users\perer\AppData\Local\Temp\ipykernel_14940\2928560636.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tft_train_df['well'] = well
#     time_step           dhp        dht           whp        wht     choke  \
# 0           0  1.632420e+07  81.775019  5.659456e+06  55.487664  0.266403
# 1      160564  1.472851e+07  81.779837  4.354705e+06  63.998024  0.639000
# 2      164427  1.522295e+07  81.802201  4.783272e+06  61.866347  0.527622
# 3      166435  1.629692e+07  81.792378  5.614163e+06  59.510117  0.280901
# 4      167065  1.635270e+07  81.797316  5.636706e+06  60.449022  0.281301
# ..        ...           ...        ...           ...        ...       ...
# 65    1334921  0.000000e+00   0.000000  3.507099e+06  60.261279  0.772418
# 66    1356091  0.000000e+00   0.000000  3.271542e+06  61.629887  0.863000
# 67    1398428  0.000000e+00   0.000000  3.145420e+06  64.110234  0.999976
# 68    1399424  0.000000e+00   0.000000  3.171013e+06  64.278815  0.924723
# 69    1402430  0.000000e+00   0.000000  3.146037e+06  63.391003  0.909765
#
#              dcp     qo_mpfm       qg_mpfm       qw_mpfm well
# 0   2.119695e+06   46.163504   5770.970155      0.005544  W06
# 1   2.223913e+06  161.678220  19730.379068      0.156350  W06
# 2   2.177317e+06  129.344960  15752.985564      0.002812  W06
# 3   2.112620e+06   47.306754   5869.085017      0.008071  W06
# 4   2.109265e+06   48.185071   5968.807636      0.001276  W06
# ..           ...         ...           ...           ...  ...
# 65  2.213360e+06  156.707003  19250.863561    692.881260  W06
# 66  2.222820e+06  164.725428  20459.756094  22477.333547  W06
# 67  2.245061e+06  182.844914  22538.869193    968.140703  W06
# 68  2.228837e+06  173.725389  21173.870221   3888.404818  W06
# 69  2.221008e+06  168.226264  20420.954883   3164.458193  W06
#
# [70 rows x 11 columns]

# %%
tf_nn = TemporalFusionTransformerModel(train_data=tft_train_df.head(200000))
time_varying_known_reals = ['dhp', 'dht', 'whp', 'wht', 'choke', 'dcp']
target_fields=['qg_mpfm']
raw_predictions, best_tft = tf_nn.train(time_idx='time_step', time_series_idx=['well'], target_fields=target_fields, time_varying_known_reals=time_varying_known_reals)
# Out:
# CUDA available: True
# CUDA version: 12.6
# CUDA version: NVIDIA GeForce RTX 3050 6GB Laptop GPU
# C:\Users\perer\AppData\Local\pypoetry\Cache\virtualenvs\vfm-Whcif8Lq-py3.11\Lib\site-packages\pytorch_forecasting\data\timeseries\_timeseries.py:1850: UserWarning: Min encoder length and/or min_prediction_idx and/or min prediction length and/or lags are too large for 1 series/groups which therefore are not present in the dataset index. This means no predictions can be made for those series. First 10 removed groups: [{'__group_id__well': 'W06'}]
#   warnings.warn(
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 4
#       2 time_varying_known_reals = ['dhp', 'dht', 'whp', 'wht', 'choke', 'dcp']
#       3 target_fields=['qg_mpfm']
# ----> 4 raw_predictions, best_tft = tf_nn.train(time_idx='time_step', time_series_idx=['well'], target_fields=target_fields, time_varying_known_reals=time_varying_known_reals)
#
# File ~\Documents\Code\pcperera\vfm\src\vfm\model\nn\tft.py:34, in TemporalFusionTransformerModel.train(self, time_idx, time_series_idx, target_fields, time_varying_known_reals)
#      31     normalizers.append(GroupNormalizer(groups=time_series_idx, transformation="softplus"))
#      33 # Training data set timeseries
# ---> 34 training_data_timeseries = TimeSeriesDataSet(
#      35     self.__train_data,
#      36     time_idx=time_idx,
#      37     group_ids=time_series_idx,
#      38     target=target_fields if len(target_fields) < 0 else target_fields[0],
#      39     min_encoder_length=self.__max_encoder_length // 2,
#      40     max_encoder_length=self.__max_encoder_length,
#      41     min_prediction_length=self.__max_prediction_length // 2,
#      42     max_prediction_length=self.__max_prediction_length,
#      43     time_varying_known_reals=time_varying_known_reals,
#      44     time_varying_unknown_reals=target_fields,
#      45     add_relative_time_idx=True,
#      46     add_target_scales=True,
#      47     add_encoder_length=True,
#      48     # target_normalizer=MultiNormalizer(normalizers=normalizers),
#      49     allow_missing_timesteps=True,
#      50 )
#      52 # Validation data set timeseries
#      53 validation_data_timeseries = TimeSeriesDataSet.from_dataset(training_data_timeseries, self.__train_data, predict=True, stop_randomization=True)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\vfm-Whcif8Lq-py3.11\Lib\site-packages\pytorch_forecasting\data\timeseries\_timeseries.py:646, in TimeSeriesDataSet.__init__(self, data, time_idx, target, group_ids, weight, max_encoder_length, min_encoder_length, min_prediction_idx, min_prediction_length, max_prediction_length, static_categoricals, static_reals, time_varying_known_categoricals, time_varying_known_reals, time_varying_unknown_categoricals, time_varying_unknown_reals, variable_groups, constant_fill_strategy, allow_missing_timesteps, lags, add_relative_time_idx, add_target_scales, add_encoder_length, target_normalizer, categorical_encoders, scalers, randomize_length, predict_mode)
#     639     assert target not in self._scalers, msg
#     641 # index for getitem based resampling
#     642 # ----------------------------------
#     643 # NOTE: this should be refactored and probably in a DataLoader
#     644
#     645 # create index
# --> 646 self.index = self._construct_index(data, predict_mode=self.predict_mode)
#     648 # data conversion to torch tensors
#     649 # --------------------------------
#     650
#     651 # convert to torch tensor for high performance data loading later
#     652 self.data = self._data_to_tensors(data)
#
# File ~\AppData\Local\pypoetry\Cache\virtualenvs\vfm-Whcif8Lq-py3.11\Lib\site-packages\pytorch_forecasting\data\timeseries\_timeseries.py:1864, in TimeSeriesDataSet._construct_index(self, data, predict_mode)
#    1850     warnings.warn(
#    1851         "Min encoder length and/or min_prediction_idx and/or min "
#    1852         "prediction length and/or lags are too large for "
#    (...)   1858         UserWarning,
#    1859     )
#    1860 msg = (
#    1861     "filters should not remove entries all entries - "
#    1862     "check encoder/decoder lengths and lags"
#    1863 )
# -> 1864 assert len(df_index) > 0, msg
#    1866 minimal_columns = [
#    1867     "index_start",
#    1868     "index_end",
#    (...)   1871     "sequence_id",
#    1872 ]
#    1873 if predict_mode and "sequence_id" in df_index.columns:
#
# AssertionError: filters should not remove entries all entries - check encoder/decoder lengths and lags

# %%
import matplotlib.pyplot as plt

for well_idx in range(1):  # Plot all workload timeseries
    # for field_idx in range(len(target_fields)):
        fig, ax = plt.subplots(figsize=(10, 4))
        best_tft.plot_prediction(x=raw_predictions.x, out=raw_predictions.output, idx=well_idx, add_loss_to_title=False, ax=ax)
        current_title = ax.get_title()
        new_title = f' {well} qg_mpfm - known reals {time_varying_known_reals} \n' + current_title
        ax.set_title(new_title)
