# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from src.vfm.connection import Connection
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
connection = Connection()
# Get client
client = connection.get_client()

# %%
output_dir = r"doc\thesis\images"
os.makedirs(output_dir, exist_ok=True)

for i in range(6, 7):
    try:
        well = f"W0{i}" if i < 10 else f"W{i}"
        df_raw = connection.get_data(client, well=well)

        # Save data
        df_raw.to_csv(rf"data\{well}.csv", index=True)

        # Print stats
        min_ts = df_raw.index.min()
        max_ts = df_raw.index.max()
        print(well, df_raw.shape[0], f"min_ts={min_ts}", f"max_ts={max_ts}")

        print(df_raw["whp"].describe)

        # Plot each independent variable vs time
        for col in df_raw.columns:
            plt.figure(figsize=(10, 4))
            plt.plot(df_raw.index, df_raw[col],  marker="o", linestyle="")
            plt.title(f"{well} – {col} over time:  min_ts={min_ts}, max_ts={max_ts}")
            plt.xlabel("Time")
            plt.ylabel(col)
            plt.tight_layout()

            # Save plot
            plt.savefig(os.path.join(output_dir, f"{well}_{col}.png"))
            plt.close()

    except Exception:
        pass
# Out:
# W06 377 min_ts=2017-03-06 02:38:30 max_ts=2023-05-07 07:24:00
# <bound method NDFrame.describe of 2017-03-06 02:38:30    41.730152
# 2017-03-06 10:21:00    44.904948
# 2017-04-09 06:46:30    34.643653
# 2017-04-12 18:15:30    34.680728
# 2017-04-13 21:09:30    34.100336
#                          ...
# 2023-01-16 21:25:00          NaN
# 2023-01-16 23:23:00          NaN
# 2023-01-17 11:19:30    26.136629
# 2023-01-17 20:24:00          NaN
# 2023-05-07 07:24:00    25.029827
# Name: whp, Length: 377, dtype: float64>

# %%
isinstance(df_raw.index, pd.DatetimeIndex)
# Out:
# True

# %%
df_raw.index.is_monotonic_increasing
# Out:
# True
